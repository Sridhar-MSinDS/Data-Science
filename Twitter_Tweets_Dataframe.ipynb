# %%
# !pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.13-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2024.2.2)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.13

# %%
import pandas as pd
from ntscraper import Nitter

# Initialize the scraper
scraper = Nitter(log_level=1, skip_instance_check=False)

# Retrieve tweets
tweets = scraper.get_tweets('elonmusk', mode='user', number=5)

# Check if tweets were found
if tweets['tweets']:
    # Create a list to hold each tweet's data as a dictionary
    data = []
    for tweet in tweets['tweets']:
        # Each tweet's details are stored as a dictionary
        tweet_data = {
            'date': tweet['date'],
            'text': tweet['text']
               # Assuming retweets count is available
        }
        data.append(tweet_data)
        print(tweet['text'])

    # Convert list of dictionaries to DataFrame
    tweet_df = pd.DataFrame(data)
    print(tweet_df)

else:
    print("No tweets found.")
# Out:
# Testing instances: 100%|██████████| 77/77 [01:10<00:00,  1.09it/s]
# INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for elonmusk: 5 tweets, 0 threads...
# The latest version of Tesla’s (supervised) self-driving will blow your mind
# View of yesterday’s @Starlink deploy during an orbital sunrise
# How to vote your Tesla shares
# 𝕏 is the #1 news app on the AppStore in Argentina, leading both the free and grossing categories. 🥇
# At the risk of sounding elitist, I prefer IHOP
#                          date  \
# 0   May 8, 2024 · 2:08 AM UTC
# 1  May 7, 2024 · 10:45 PM UTC
# 2   May 7, 2024 · 6:43 PM UTC
# 3   May 7, 2024 · 2:05 PM UTC
# 4   May 7, 2024 · 6:37 PM UTC
#
#                                                 text
# 0  The latest version of Tesla’s (supervised) sel...
# 1  View of yesterday’s @Starlink deploy during an...
# 2                      How to vote your Tesla shares
# 3  𝕏 is the #1 news app on the AppStore in Argent...
# 4     At the risk of sounding elitist, I prefer IHOP

# %%
# Display dataframe with 'tweet timings', 'text' as columns
tweet_df.head()
# Out:
#                          date  \
# 0   May 8, 2024 · 2:08 AM UTC
# 1  May 7, 2024 · 10:45 PM UTC
# 2   May 7, 2024 · 6:43 PM UTC
# 3   May 7, 2024 · 2:05 PM UTC
# 4   May 7, 2024 · 6:37 PM UTC
#
#                                                 text
# 0  The latest version of Tesla’s (supervised) sel...
# 1  View of yesterday’s @Starlink deploy during an...
# 2                      How to vote your Tesla shares
# 3  𝕏 is the #1 news app on the AppStore in Argent...
# 4     At the risk of sounding elitist, I prefer IHOP
